# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'/Users/chaitanyanarayanavaram/Desktop/Data Mining/Final project/omited1.1.csv')

# %%
df
# Out:
#        Unnamed: 0  encounter_id  patient_nbr  race  gender  age  \
# 0               0       2278392      8222157     0       0    0
# 1               1        149190     55629189     0       0    1
# 2               2        500364     82442376     0       1    3
# 3               3         16680     42519267     0       1    4
# 4               4         35754     82637451     0       1    5
# ...           ...           ...          ...   ...     ...  ...
# 65754       65754     443842016    183087545     0       0    7
# 65755       65755     443842022    188574944     3       0    4
# 65756       65756     443842070    140199494     3       0    6
# 65757       65757     443842340    120975314     0       0    8
# 65758       65758     443867222    175429310     0       1    7
#
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                      6                        25                    1
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace = True)
df.drop(columns=['glipizide-metformin'],inplace = True)
df.drop(columns=['glyburide-metformin'],inplace = True)
df.drop(columns=['tolazamide'],inplace = True)
df.drop(columns=['chlorpropamide'],inplace = True)

# %%
df.drop(columns=['encounter_id'],inplace = True)
df.drop(columns=['patient_nbr'],inplace = True)

# %%
df
# Out:
#        race  gender  age  admission_type_id  discharge_disposition_id  \
# 0         0       0    0                  6                        25
# 1         0       0    1                  1                         1
# 2         0       1    3                  1                         1
# 3         0       1    4                  1                         1
# 4         0       1    5                  2                         1
# ...     ...     ...  ...                ...                       ...
# 65754     0       0    7                  1                         1
# 65755     3       0    4                  1                         1
# 65756     3       0    6                  1                         1
# 65757     0       0    8                  1                         1
# 65758     0       1    7                  1                         1
#
#        admission_source_id  time_in_hospital  medical_specialty  \
# ...

# %%
df["readmitted"].replace({3: 1}, inplace=True)

# %%
df
# Out:
#        race  gender  age  admission_type_id  discharge_disposition_id  \
# 0         0       0    0                  6                        25
# 1         0       0    1                  1                         1
# 2         0       1    3                  1                         1
# 3         0       1    4                  1                         1
# 4         0       1    5                  2                         1
# ...     ...     ...  ...                ...                       ...
# 65754     0       0    7                  1                         1
# 65755     3       0    4                  1                         1
# 65756     3       0    6                  1                         1
# 65757     0       0    8                  1                         1
# 65758     0       1    7                  1                         1
#
#        admission_source_id  time_in_hospital  medical_specialty  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import scipy.stats as stats


import statsmodels.api as sm
from statsmodels.graphics.gofplots import qqplot

# %%
def Box_plots(df):
    plt.figure(figsize=(10,4))
    plt.title("Box Plot")
    sns.boxplot(df)
    plt.show()
Box_plots(df["time_in_hospital"])
# Out:
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['time_in_hospital'])
plt.title("Box Plot before mean imputation" )
plt.show()
for i in df['time_in_hospital']:
    q1= df['time_in_hospital' ].quantile(0.25)
    q3 = df['time_in_hospital' ].quantile(0.75)
    iqr = q3-q1
    Lower_tail = q1 - 1.5 * iqr
    Upper_tail = q3 + 1.5 * iqr
    if i > Upper_tail or i < Lower_tail:
        df['time_in_hospital'] = df['time_in_hospital'].replace(i, np.mean(df['time_in_hospital']))
sns.boxplot(df['time_in_hospital'])
plt.title("Box Plot after mean imputation")
plt.show()
# Out:
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['num_lab_procedures'])
plt.title("Box Plot before mean imputation" )
plt.show()
for i in df['num_lab_procedures']:
    q1= df['num_lab_procedures' ].quantile(0.25)
    q3 = df['num_lab_procedures' ].quantile(0.75)
    iqr = q3-q1
    Lower_tail = q1 - 1.5 * iqr
    Upper_tail = q3 + 1.5 * iqr
    if i > Upper_tail or i < Lower_tail:
        df['num_lab_procedures'] = df['num_lab_procedures'].replace(i, np.mean(df['num_lab_procedures']))
sns.boxplot(df['num_lab_procedures'])
plt.title("Box Plot after mean imputation")
plt.show()
# Out:
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['num_procedures'])
plt.title("Box Plot before mean imputation" )
plt.show()
for i in df['num_procedures']:
    q1= df['num_procedures' ].quantile(0.25)
    q3 = df['num_procedures' ].quantile(0.75)
    iqr = q3-q1
    Lower_tail = q1 - 1.5 * iqr
    Upper_tail = q3 + 1.5 * iqr
    if i > Upper_tail or i < Lower_tail:
        df['num_procedures'] = df['num_procedures'].replace(i, np.mean(df['num_procedures']))
sns.boxplot(df['num_procedures'])
plt.title("Box Plot after mean imputation")
plt.show()
# Out:
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['num_medications'])
plt.title("Box Plot before mean imputation" )
plt.show()
for i in df['num_medications']:
    q1= df['num_medications' ].quantile(0.25)
    q3 = df['num_medications' ].quantile(0.75)
    iqr = q3-q1
    Lower_tail = q1 - 1.5 * iqr
    Upper_tail = q3 + 1.5 * iqr
    if i > Upper_tail or i < Lower_tail:
        df['num_medications'] = df['num_medications'].replace(i, np.mean(df['num_medications']))
sns.boxplot(df['num_medications'])
plt.title("Box Plot after mean imputation")
plt.show()
# Out:
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['number_emergency'])
plt.title("Box Plot before mean imputation" )
plt.show()
for i in df['number_emergency']:
    q1= df['number_emergency' ].quantile(0.25)
    q3 = df['number_emergency' ].quantile(0.75)
    iqr = q3-q1
    Lower_tail = q1 - 1.5 * iqr
    Upper_tail = q3 + 1.5 * iqr
    if i > Upper_tail or i < Lower_tail:
        df['number_emergency'] = df['number_emergency'].replace(i, np.mean(df['number_emergency']))
sns.boxplot(df['number_emergency'])
plt.title("Box Plot after mean imputation")
plt.show()
# Out:
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['number_inpatient'])
plt.title("Box Plot before mean imputation" )
plt.show()
for i in df['number_inpatient']:
    q1= df['number_inpatient' ].quantile(0.25)
    q3 = df['number_inpatient' ].quantile(0.75)
    iqr = q3-q1
    Lower_tail = q1 - 1.5 * iqr
    Upper_tail = q3 + 1.5 * iqr
    if i > Upper_tail or i < Lower_tail:
        df['number_inpatient'] = df['number_inpatient'].replace(i, np.mean(df['number_inpatient']))
sns.boxplot(df['number_inpatient'])
plt.title("Box Plot after mean imputation")
plt.show()
# Out:
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(df['number_diagnoses'])
plt.title("Box Plot before mean imputation" )
plt.show()
for i in df['number_diagnoses']:
    q1= df['number_diagnoses' ].quantile(0.25)
    q3 = df['number_diagnoses' ].quantile(0.75)
    iqr = q3-q1
    Lower_tail = q1 - 1.5 * iqr
    Upper_tail = q3 + 1.5 * iqr
    if i > Upper_tail or i < Lower_tail:
        df['number_diagnoses'] = df['number_diagnoses'].replace(i, np.mean(df['number_diagnoses']))
sns.boxplot(df['number_diagnoses'])
plt.title("Box Plot after mean imputation")
plt.show()
# Out:
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
feature_cols = ['race', 'gender', 'age',
       'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
       'time_in_hospital', 'medical_specialty', 'num_lab_procedures',
       'num_procedures', 'num_medications', 'number_outpatient',
       'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3',
       'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin',
       'repaglinide', 'nateglinide', 'glimepiride',
       'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone',
       'rosiglitazone', 'acarbose', 'insulin', 'change', 'diabetesMed']
X = df[feature_cols] # Features
y = df.readmitted # Target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8279349148418491

# %%
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9102037712895377

# %%
from sklearn import tree
tree.plot_tree(clf)
# Out:
# [Text(167.4, 190.26, 'X[4] <= 1.5\nentropy = 0.427\nsamples = 52607\nvalue = [4588, 48019]'),
#  Text(83.7, 135.9, 'X[13] <= 0.008\nentropy = 0.36\nsamples = 32521\nvalue = [2222, 30299]'),
#  Text(41.85, 81.53999999999999, 'X[6] <= 6.5\nentropy = 0.331\nsamples = 29123\nvalue = [1775, 27348]'),
#  Text(20.925, 27.180000000000007, 'entropy = 0.314\nsamples = 25680\nvalue = [1457, 24223]'),
#  Text(62.775000000000006, 27.180000000000007, 'entropy = 0.444\nsamples = 3443\nvalue = [318, 3125]'),
#  Text(125.55000000000001, 81.53999999999999, 'X[13] <= 0.098\nentropy = 0.562\nsamples = 3398\nvalue = [447, 2951]'),
#  Text(104.625, 27.180000000000007, 'entropy = 0.759\nsamples = 374\nvalue = [82, 292]'),
#  Text(146.475, 27.180000000000007, 'entropy = 0.531\nsamples = 3024\nvalue = [365, 2659]'),
#  Text(251.10000000000002, 135.9, 'X[13] <= 0.007\nentropy = 0.523\nsamples = 20086\nvalue = [2366, 17720]'),
# ...

# %%
from sklearn.metrics import classification_report 
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1181
#            1       0.91      1.00      0.95     11971
#
#     accuracy                           0.91     13152
#    macro avg       0.46      0.50      0.48     13152
# weighted avg       0.83      0.91      0.87     13152
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/chaitanyanarayanavaram/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[    0,  1181],
#        [    0, 11971]])

# %%
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3,max_leaf_nodes=5)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9102037712895377

# %%
clf = DecisionTreeClassifier(criterion="gini", max_depth=4,max_leaf_nodes=5)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9102037712895377

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
import numpy as np
import matplotlib.pyplot as plt

# function for fitting trees of various depths on the training data using cross-validation
def run_cross_validation_on_trees(X, y, tree_depths, cv=5, scoring='accuracy'):
    cv_scores_list = []
    cv_scores_std = []
    cv_scores_mean = []
    accuracy_scores = []
    for depth in tree_depths:
        tree_model = DecisionTreeClassifier(max_depth=depth)
        cv_scores = cross_val_score(tree_model, X, y, cv=cv, scoring=scoring)
        cv_scores_list.append(cv_scores)
        cv_scores_mean.append(cv_scores.mean())
        cv_scores_std.append(cv_scores.std())
        accuracy_scores.append(tree_model.fit(X, y).score(X, y))
    cv_scores_mean = np.array(cv_scores_mean)
    cv_scores_std = np.array(cv_scores_std)
    accuracy_scores = np.array(accuracy_scores)
    return cv_scores_mean, cv_scores_std, accuracy_scores
  
# function for plotting cross-validation results
def plot_cross_validation_on_trees(depths, cv_scores_mean, cv_scores_std, accuracy_scores, title):
    fig, ax = plt.subplots(1,1, figsize=(15,5))
    ax.plot(depths, cv_scores_mean, '-o', label='mean cross-validation accuracy', alpha=0.9)
    ax.fill_between(depths, cv_scores_mean-2*cv_scores_std, cv_scores_mean+2*cv_scores_std, alpha=0.2)
    ylim = plt.ylim()
    ax.plot(depths, accuracy_scores, '-*', label='train accuracy', alpha=0.9)
    ax.set_title(title, fontsize=16)
    ax.set_xlabel('Tree depth', fontsize=14)
    ax.set_ylabel('Accuracy', fontsize=14)
    ax.set_ylim(ylim)
    ax.set_xticks(depths)
    ax.legend()

# fitting trees of depth 1 to 24
sm_tree_depths = range(1,40)
sm_cv_scores_mean, sm_cv_scores_std, sm_accuracy_scores = run_cross_validation_on_trees(X_train, y_train, sm_tree_depths)

# plotting accuracy
plot_cross_validation_on_trees(sm_tree_depths, sm_cv_scores_mean, sm_cv_scores_std, sm_accuracy_scores, 
                               'Accuracy per decision tree depth on training data')

# %%
path = clf.cost_complexity_pruning_path(X_train,y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
clfs = []
for ccp_alpha in ccp_alphas:
    clf = tree.DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha, max_leaf_nodes=10)
    clf.fit(X_train, y_train)
    clfs.append(clf)
print("Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
      clfs[-1].tree_.node_count, ccp_alphas[-1]))
# Out:
# Number of nodes in the last tree is: 3 with ccp_alpha: 0.0011551971311218323

# %%
fig, ax = plt.subplots()
ax.plot(ccp_alphas[:-1], impurities[:-1], marker="o", drawstyle="steps-post")
ax.set_xlabel("effective alpha")
ax.set_ylabel("total impurity of leaves")
ax.set_title("Total Impurity vs effective alpha for training set")
# Out:
# Text(0.5, 1.0, 'Total Impurity vs effective alpha for training set')

# %%
train_scores = [clf.score(X_train, y_train) for clf in clfs]
test_scores = [clf.score(X_test, y_test) for clf in clfs]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker="o", label="train", drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker="o", label="test", drawstyle="steps-post")
ax.legend()
plt.show()

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
plot_confusion_matrix(clf,
                      X_test,
                  y_test)

# %%
plot_confusion_matrix(clf,
                     y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-832789688eea> in <module>
# ----> 1 plot_confusion_matrix(clf,
#       2                      y_test, y_pred)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_plot/confusion_matrix.py in plot_confusion_matrix(estimator, X, y_true, labels, sample_weight, normalize, display_labels, include_values, xticks_rotation, values_format, cmap, ax, colorbar)
#     258         raise ValueError("plot_confusion_matrix only supports classifiers")
#     259
# --> 260     y_pred = estimator.predict(X)
# ...

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[    0,  1181],
#        [    0, 11971]])

# %%
df
# Out:
#        race  gender  age  admission_type_id  discharge_disposition_id  \
# 0         0       0    0                  6                        25
# 1         0       0    1                  1                         1
# 2         0       1    3                  1                         1
# 3         0       1    4                  1                         1
# 4         0       1    5                  2                         1
# ...     ...     ...  ...                ...                       ...
# 65754     0       0    7                  1                         1
# 65755     3       0    4                  1                         1
# 65756     3       0    6                  1                         1
# 65757     0       0    8                  1                         1
# 65758     0       1    7                  1                         1
#
#        admission_source_id  time_in_hospital  medical_specialty  \
# ...
